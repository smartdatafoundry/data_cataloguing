# %%
import pandas as pd

# %%
df = pd.read_csv('mock_data/weekly_financials.csv')

# %%
df2 = pd.read_csv('synthetic_data/synthetic_data.csv')

# %%
df.head()
# Out:
#              id         city sex        date  salary  bonus  investment  rent  \
# 0  ecbddaafbcdf  Los Angeles   F  2025-01-01    3468   1228        1475  2199
# 1  feebadaffaed      Chicago   F  2025-01-08    2788   1574         611   668
# 2  ceddaabafbfc  Los Angeles   M  2025-01-15    4519    327          62  1863
# 3  eebaaeabcddd     New York   M  2025-01-22    6288   1241         359  2268
# 4  bcaedafdaead  Los Angeles   F  2025-01-29    2277    606         631  1927
#
#    groceries  utilities  entertainment
# 0        413        344            342
# 1        734        307            431
# 2        394        289            405
# 3        418        354             69
# 4        425        369             71

# %%
df2
# Out:
#     id  city  sex  date  salary  bonus  investment  rent  groceries  \
# 0  NaN   NaN  NaN   NaN    2162      0           5   502        102
# 1  NaN   NaN  NaN   NaN    2162      0           5   502        102
# 2  NaN   NaN  NaN   NaN    2162      0           5   502        102
# 3  NaN   NaN  NaN   NaN    2162      0           5   502        102
# 4  NaN   NaN  NaN   NaN    2162      0           5   502        102
# ..  ..   ...  ...   ...     ...    ...         ...   ...        ...
# 95 NaN   NaN  NaN   NaN    2162      0           5   502        102
# 96 NaN   NaN  NaN   NaN    2162      0           5   502        102
# 97 NaN   NaN  NaN   NaN    2162      0           5   502        102
# 98 NaN   NaN  NaN   NaN    2162      0           5   502        102
# 99 NaN   NaN  NaN   NaN    2162      0           5   502        102
#
#     utilities  entertainment
# 0          65             57
# 1          65             57
# 2          65             57
# 3          65             57
# ...
