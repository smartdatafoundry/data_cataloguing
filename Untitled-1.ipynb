# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('test_data/ifs_2019-2024_datasets_without_zeros/ifs_lad_exp_means_2019-2024.csv')   
df2 = pd.read_csv('test_data/ifs_2019-2024_datasets_without_zeros/ifs_msoa_exp_means_2019-2024.csv')

# %%
df2
# Out:
#        year   msoa11cd  mean_expenditure  mean_expenditure_committed_mortgage  \
# 0      2019  E02003569        572.776437                           605.832119
# 1      2019  E02001661        486.163169                           430.586168
# 2      2019  E02004263       1133.583322                           873.174623
# 3      2019  E02002492        712.585925                           656.437000
# 4      2019  E02004484        863.290394                           652.497955
# ...     ...        ...               ...                                  ...
# 50863  2024  E02001949       1018.382898                           552.960884
# 50864  2024  S02001976        717.952569                           444.477568
# 50865  2024  E02001744       1007.074934                           760.595491
# 50866  2024  E02002455       1030.483994                           516.311772
# 50867  2024  E02002515        852.659057                           507.933720
#
# ...

# %%
df.drop(columns='count', axis=1, inplace=True)
df2.drop(columns='count', axis=1, inplace=True)

# %%
df.to_csv('test_data/ifs_2019-2024_datasets_without_zeros/ifs_lad_exp_means_2019-2024.csv', index=False)
df2.to_csv('test_data/ifs_2019-2024_datasets_without_zeros/ifs_msoa_exp_means_2019-2024.csv', index=False)

# %%
df.to_parquet('resulting_data/ifs_msoa_exp_means_2019-2024.parquet', index=False)
df2.to_parquet('resulting_data/ifs_msoa_exp_means_2019.parquet', index=False)
df3.to_parquet('resulting_data/ifs_lad_exp_means_2019-2024.parquet', index=False)
df4.to_parquet('resulting_data/ifs_lad_exp_means_2019.parquet', index=False)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df.to_parquet('resulting_data/ifs_msoa_exp_means_2019-2024.parquet', index=False)
#       2 df2.to_parquet('resulting_data/ifs_msoa_exp_means_2019.parquet', index=False)
#       3 df3.to_parquet('resulting_data/ifs_lad_exp_means_2019-2024.parquet', index=False)
#
# File ~/repo/data_cataloguing/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
